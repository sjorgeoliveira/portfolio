# %% [markdown]
# # Churn Rate Management
# Gestão da taxa de rotatividade
#
# ## Reduction Customer Churn Rate Using Data Analytics
# ---
# Redução da taxa de rotatividade do cliente usando análise de dados

# %% [markdown]
# # 1.0 The Context and Understanding the Business
# ---
# O Contexto e Compreensão do Negócio

# %% [markdown]
# ## 1.1 What Is Churn Rate?
# O que é taxa de rotatividade?

# %% [markdown]
# Churn rate, when applied to a customer base, refers to the proportion of contractual customers or subscribers who leave a supplier during a given time period. It is a possible indicator of customer dissatisfaction, cheaper and/or better offers from the competition, more successful sales and/or marketing by the competition, or reasons having to do with the customer life cycle.
#
# A taxa de desligamento, quando aplicada a uma base de clientes, refere-se à proporção de clientes ou assinantes contratuais que deixam um fornecedor durante um determinado período. É um possível indicador de insatisfação do cliente, ofertas mais baratas e / ou melhores da concorrência, vendas e / ou marketing mais bem-sucedidas da concorrência ou motivos relacionados com o ciclo de vida do cliente.

# %% [markdown]
# ## 1.2 What Factors are Used to Assess Churn Rate?
# Quais fatores são usados para avaliar a taxa de rotatividade?

# %% [markdown]
# Churn is closely related to the concept of average customer life time.
# For example, an annual churn rate of 25 percent implies an average customer life of four years.<br>
# An annual churn rate of 33 percent implies an average customer life of three years.<br>
#
# The churn rate can be minimized by creating barriers which discourage customers to change suppliers (contractual binding periods, use of proprietary technology, value-added services, unique business models, etc.), or through retention activities such as loyalty programs.<br>
# It is possible to overstate the churn rate, as when a consumer drops the service but then restarts it within the same year. Thus, a clear distinction needs to be made between "gross churn", the total number of absolute disconnections, and "net churn", the overall loss of subscribers or members.<br>
#
# The difference between the two measures is the number of new subscribers or members that have joined during the same period.<br>
# Suppliers may find that if they offer a loss-leader "introductory special", it can lead to a higher churn rate and subscriber abuse, as some subscribers will sign on, let the service lapse, then sign on again to take continuous advantage of current specials.
#
# ==> Português <==
# O churn está intimamente relacionado ao conceito de tempo médio de vida do cliente.
# Por exemplo, uma taxa de rotatividade anual de 25% implica em uma vida média do cliente de quatro anos. <br>
# Uma taxa de rotatividade anual de 33 por cento implica uma vida média do cliente de três anos. <br>
#
# A taxa de rotatividade pode ser minimizada criando barreiras que desencorajam os clientes a mudar de fornecedores (períodos de vinculação contratual, uso de tecnologia proprietária, serviços de valor agregado, modelos de negócios exclusivos, etc.) ou por meio de atividades de retenção, como programas de fidelidade. <br>
# É possível exagerar a taxa de churn, como quando um consumidor descarta o serviço, mas o reinicia no mesmo ano. Portanto, uma distinção clara deve ser feita entre "churn bruto", o número total de desconexões absolutas, e "churn líquido", a perda geral de assinantes ou membros. <br>
#
# A diferença entre as duas medidas é o número de novos assinantes ou membros que aderiram durante o mesmo período. <br>
# Os fornecedores podem descobrir que, se oferecerem um "especial introdutório" líder em perdas, isso pode levar a uma taxa de rotatividade mais alta e abuso de assinantes, já que alguns assinantes assinam, deixam o serviço expirar e, em seguida, assinam novamente para tirar vantagem contínua da corrente especiais.

# %% [markdown]
# ## 1.3 What Is Churn Management?
# O que é gerenciamento de rotatividade?

# %% [markdown]
# Churn management is the art of identifying the valuable customers, who are likely to churn from a company and executing proactive steps to retain them.
#
# O gerenciamento de churn é a arte de identificar os clientes valiosos, que provavelmente sairão de uma empresa e executar etapas proativas para retê-los.

# %% [markdown]
# ## 1.4 Challenges to Successful Churn Management
#
# Desafios para uma gestão de churn bem-sucedida

# %% [markdown]
# - **Inefficient data management.** An inability to access the right data when it’s needed causes problematic delays.
#
# - **No groupwide churn  modeling framework.** Without it, banks can’t generate complex, meaningful churn measures and get a big picture of groupwide churn.
#
# - **Constant rework.** Analysts can’t change model parameters easily, which results in too much duplication of effort and negatively affects a bank’s efficiency ratio.
#
# - **Insufficient churn tools.** Without a robust churn solution, banks can’t identify customer on churn risk often enough to effectively manage churn.
#
# - **Cumbersome reporting.** Manual, spreadsheet-based reporting processes overburden analysts and IT.
#
# > Português
#
# - ** Gerenciamento de dados ineficiente. ** A incapacidade de acessar os dados certos quando necessário causa atrasos problemáticos.
#
# - ** Sem estrutura de modelagem de rotatividade em todo o grupo. ** Sem ela, os bancos não podem gerar medidas de rotatividade complexas e significativas e ter uma visão geral da rotatividade em todo o grupo.
#
# - ** Retrabalho constante. ** Os analistas não podem alterar os parâmetros do modelo facilmente, o que resulta em muita duplicação de esforços e afeta negativamente o índice de eficiência de um banco.
#
# - ** Ferramentas de churn insuficientes. ** Sem uma solução robusta de churn, os bancos não conseguem identificar o risco de churn de clientes com frequência suficiente para gerenciar com eficácia o churn.
#
# - ** Relatórios complicados. ** Os processos de relatórios manuais e baseados em planilhas sobrecarregam os analistas e a TI.

# %% [markdown]
# ## 1.5 Best Practices in Churn Rate Management
#
# Melhores práticas na gestão da taxa de rotatividade

# %% [markdown]
# The first step in effective churn management is to gain a complete understanding of a bank’s overall churn report by viewing churn at the individual and customer levels.
#
# While banks strive for an integrated understanding of churn profiles, much information is often scattered among business units. Without a thorough churn assessment, banks have no way of knowing if customer will or not entry in "churn mode".
#
# The key to reducing churn rates – and ensuring that customer maintain his fidelity – is to implement an integrated, analytics churn solution.
# This solution should get banks up and running quickly with simple portfolio measures.
# The solution should include:
#
# - Better model management that spans the entire modeling life cycle;
# - Real-time predict churn scoring;
# - Data visualization capabilities and business intelligence tools that get important information into the hands of those who need it, when they need it.
#
# > Português
#
# A primeira etapa para uma gestão de churn eficaz é obter uma compreensão completa do relatório de churn geral de um banco, visualizando a churn nos níveis individual e de cliente.
#
# Enquanto os bancos buscam uma compreensão integrada dos perfis de rotatividade, muitas informações costumam estar espalhadas entre as unidades de negócios. Sem uma avaliação completa do churn, os bancos não têm como saber se o cliente entrará ou não no "modo churn".
#
# A chave para reduzir as taxas de churn - e garantir que o cliente mantenha sua fidelidade - é implementar uma solução integrada de churn analítica.
# Essa solução deve colocar os bancos em funcionamento rapidamente com medidas simples de portfólio.
# A solução deve incluir:
#
# - Melhor gerenciamento de modelo que abrange todo o ciclo de vida da modelagem;
# - Previsão de pontuação de churn em tempo real;
# - Capacidades de visualização de dados e ferramentas de business intelligence que colocam informações importantes nas mãos de quem precisa, quando necessário.

# %% [markdown]
# ## 1.6 Business Metrics Definition
# Definição de métricas de negócios

# %% [markdown]
# When analyzing the performance metrics for classification machine learning algorithms, we often stumble on the **Confusion Matrix**.
#
# We need to define which case is the **best for the business**:
#
# - A) Reduce False Positives (FP) rather than False Negatives (FN).
# - B) Reduce False Negatives (FN) rather than False Positives (FP).
#
# In this project, we assumed that the best case for the business was **option (A)**, that is, ** avoid retention effort to customer that not really will entry in "churn mode"**.
#
# > Português
#
# Ao analisar as métricas de desempenho para algoritmos de aprendizado de máquina de classificação, muitas vezes tropeçamos na ** Matriz de confusão **.
#
# Precisamos definir qual caso é o ** melhor para a empresa **:
#
# - A) Reduza falsos positivos (FP) em vez de falsos negativos (FN).
# - B) Reduza os falsos negativos (FN) em vez dos falsos positivos (FP).
#
# Neste projeto, assumimos que o melhor caso para o negócio era ** opção (A) **, ou seja, ** evitar esforço de retenção de cliente que realmente não entrará em “modo de rotatividade” **.

# %% [markdown]
# ## 1.7 Business Goal
# Objetivo de Negócios

# %% [markdown]
# ### Create a business solution with Business Areas to reduce the churn rate in 10% in planned mid-term !
#
# Crie uma solução de negócios com as áreas de negócios para reduzir o churn rate em 10% no médio prazo planejado!

# %% [markdown]
# # 2.0 Imports
# ---

# %%
# data manipulation
import numpy as np
import pandas as pd

# EDA
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from collections import Counter
from scipy.stats import chi2_contingency

# data preprocessing
from tensorflow.keras.layers.experimental.preprocessing import IntegerLookup
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from tensorflow.keras.layers.experimental.preprocessing import StringLookup

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTETomek
from sklearn.metrics import classification_report

# algorithms
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers

# hyperparameter tuning
from keras_tuner import HyperModel, RandomSearch, BayesianOptimization, Hyperband

# %% [markdown]
# # 3.0 Helper functions
# ---

# %% [markdown]
# These functions helps us have a better experience while getting our results. They make the data more readable.

# %%
# sets seaborn default style
sns.set()

# sets global SEED var
SEED = 110572

# %% [markdown]
# # 4.0 Checking the data set
# ---

# %% [markdown]
# ## 4.1 Data Dictionary

# %% [markdown]
# The data set was obtained at [Kaggle](https://www.kaggle.com/mathchi/churn-for-bank-customers) in one of their Machine Learning Competition.

# %% [markdown]
# | Column          | Description                                                                                                                   |
# |:----------------|:------------------------------------------------------------------------------------------------------------------------------|
# | RowNumber       | corresponds to the record (row) number and has no effect on the output.                                          |
# | CustomerId      | contains random values and has no effect on customer leaving the bank. |
# | Surname         | the surname of a customer has no impact on their decision to leave the bank. |
# | CreditScore     | can have an effect on customer churn, since a customer with a higher credit score is less likely to leave the bank |
# | Geography       | a customer’s location can affect their decision to leave the bank. |
# | Gender          | it’s interesting to explore whether gender plays a role in a customer leaving the bank.|
# | Age             | this is certainly relevant, since older customers are less likely to leave their bank than younger ones. |
# | Tenure          | refers to the number of years that the customer has been a client of the bank|
# | Balance         | also a very good indicator of customer churn, as people with with lower balances leaves banks more than with high. |
# | NumOfProducts   | denotes whether or not a customer has a credit card. Wwith a credit card are less likely to leave the bank.|
# | HasCrCard       | If the person has a default history \(Yes; No\)                                                                |
# | IsActiveMember  | active customers are less likely to leave the bank |
# | EstimatedSalary | as balance, people with lower salaries are more likely to leave the bank compared to those with higher salaries.|
# | Exited          | whether or not the customer left the bank.|

# %% [markdown]
# ## 4.2 Loading the data set

# %%
# loads data set
df_churn = pd.read_csv("data/churn.csv")

# %%
# show columns and rows numbers
df_churn.shape
# Out:
# (10000, 14)

# %%
# checks the first five rows of the data
df_churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# Let's begin by looking at the data set `churn`. In this data set, `Exited` shows whether the customer is in "churn mode" with `1` or NOT as `0`.
#
# We have more columns within the data, and many could have a relationship with the values in `Exited`. We need to explore the data and these relationships more with further analysis to understand the impact of the data on Exited values.
#
# Checking the structure of the data as well as seeing a snapshot helps us better understand what's inside the set. Similarly, visualizations provide a high level view of the data in addition to important trends and patterns.
#
# > Português
#
# Vamos começar observando o conjunto de dados `churn`. Neste conjunto de dados, `Exited` mostra se o cliente está em" modo de rotatividade "com` 1` ou NÃO como `0`.
#
# Temos mais colunas nos dados e muitas podem ter uma relação com os valores em `Exited`. Precisamos explorar os dados e essas relações mais com análises adicionais para entender o impacto dos dados nos valores Saídos.
#
# Verificar a estrutura dos dados e também ver um instantâneo nos ajuda a entender melhor o que está dentro do conjunto. Da mesma forma, as visualizações fornecem uma visão de alto nível dos dados, além de tendências e padrões importantes.

# %%
# checks the structure of the data set
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 4.3 Descriptive Statistics

# %%
# Droping Columns that clearly does no influence Churn Column called Exited value
df_churn =  df_churn.drop(["RowNumber","CustomerId","Surname"],axis=1)

# %%
# creates a dataset for numerical attributes
num_attributes = df_churn.select_dtypes(include=['int64', 'float64'])

# creates a dataset for categorical attributes
cat_attributes = df_churn.select_dtypes(exclude=['int64', 'float64'])

# %%
# checks the operation
num_attributes.sample(2)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6362          629   34       8       0.00              2          1
# 3245          514   45       3  109032.23              1          0
#
#       IsActiveMember  EstimatedSalary  Exited
# 6362               1        180595.02       0
# 3245               1        155407.21       1

# %%
# checks the operation
cat_attributes.sample(2)
# Out:
#      Geography  Gender
# 3295     Spain  Female
# 2942    France  Female

# %%
# central tendency: mean, median
mean = pd.DataFrame(num_attributes.apply(np.mean)).T
median = pd.DataFrame(num_attributes.apply(np.median)).T

# %%
mean
# Out:
#    CreditScore      Age  Tenure       Balance  NumOfProducts  HasCrCard  \
# 0     650.5288  38.9218  5.0128  76485.889288         1.5302     0.7055
#
#    IsActiveMember  EstimatedSalary  Exited
# 0          0.5151    100090.239881  0.2037

# %%
median
# Out:
#    CreditScore   Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        652.0  37.0     5.0  97198.54            1.0        1.0
#
#    IsActiveMember  EstimatedSalary  Exited
# 0             1.0       100193.915     0.0

# %%
# distribution: std, min, max, range, skew, kurtosis
std = pd.DataFrame(num_attributes.apply(np.std)).T
min_value = pd.DataFrame(num_attributes.apply(min)).T
max_value = pd.DataFrame(num_attributes.apply(max)).T
range_value = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
skewness = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
kurtosis = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# concatenates
summary_stats = pd.concat([min_value, max_value, range_value, mean, median, std, skewness, kurtosis]).T.reset_index()
summary_stats.columns = ['attributes','min','max','range','mean','median','std','skewness','kurtosis']

# %%
# checks the operations
summary_stats
# Out:
#         attributes     min        max      range           mean      median  \
# 0      CreditScore  350.00     850.00     500.00     650.528800     652.000
# 1              Age   18.00      92.00      74.00      38.921800      37.000
# 2           Tenure    0.00      10.00      10.00       5.012800       5.000
# 3          Balance    0.00  250898.09  250898.09   76485.889288   97198.540
# 4    NumOfProducts    1.00       4.00       3.00       1.530200       1.000
# 5        HasCrCard    0.00       1.00       1.00       0.705500       1.000
# 6   IsActiveMember    0.00       1.00       1.00       0.515100       1.000
# 7  EstimatedSalary   11.58  199992.48  199980.90  100090.239881  100193.915
# 8           Exited    0.00       1.00       1.00       0.203700       0.000
#
#             std  skewness  kurtosis
# 0     96.648466 -0.071607 -0.425726
# 1     10.487282  1.011320  1.395347
# 2      2.892030  0.010991 -1.165225
# 3  62394.285254 -0.141109 -1.489412
# ...

# %% [markdown]
# As observed, we can notice no presence of outliers in dataset.
#
# `EstimatedSalary` seems to have an outlier in `min = 11.58`
#
# > Português
#
# Conforme observado, não podemos notar a presença de outliers no conjunto de dados.
#
# `EstimatedSalary` parece ter um outlier em` min = 11.58`

# %% [markdown]
# ↑↑ Double Check about unbalanced dataset.
#
# ↑↑ Verifique novamente sobre conjunto de dados não balanceado.

# %% [markdown]
# ### 4.3.1 Categorical attributes

# %%
# checks how many types we have for each atribute
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# Geography    3
# Gender       2
# dtype: int64

# %% [markdown]
# ### 4.3.2 Crosstab and Pivot Tables

# %%
# creates a cross table of the loan intent and loan status
pd.crosstab(df_churn['Geography'], df_churn['Exited'], margins=True)
# Out:
# Exited        0     1    All
# Geography
# France     4204   810   5014
# Germany    1695   814   2509
# Spain      2064   413   2477
# All        7963  2037  10000

# %% [markdown]
# As observed:
# - `Germany` and `France` have the most number of customers in churn while `Spain` has the least.
# - `France` has almost 50/50 customers both in churn and active.
# - `Spain` seems be the better marketplace for the bank.
#
# > Português
#
# Conforme observado:
# - `Alemanha` e` França` têm o maior número de clientes em rotatividade, enquanto `Espanha` tem o menor.
# - A «França» tem quase 50/50 clientes em rotatividade e ativos.
# - `Espanha` parece ser o melhor mercado para o banco.

# %%
pd.crosstab(df_churn['Gender'], df_churn['Exited'], margins=True)
# Out:
# Exited     0     1    All
# Gender
# Female  3404  1139   4543
# Male    4559   898   5457
# All     7963  2037  10000

# %% [markdown]
# As observed:
# - `Female` customers seems more often entry in churn while `Male` customers does not.
#
# > Português
#
# Conforme observado:
# - Os clientes `mulheres` parecem entrar com mais frequência na rotatividade, enquanto os clientes` homens` não.

# %%
pd.crosstab(df_churn['Age'], df_churn['Exited'], margins=True).sort_values(by=[1,"Age"], ascending=False).head(30)
# Out:
# Exited     0     1    All
# Age
# All     7963  2037  10000
# 46       135    91    226
# 40       343    89    432
# 43       209    88    297
# 45       142    87    229
# 48        88    80    168
# 47        98    77    175
# 42       244    77    321
# 49        72    75    147
# 44       184    73    257
# 39       351    72    423
# 50        63    71    134
# 41       297    69    366
# 51        53    66    119
# 52        38    64    102
# 38       414    63    477
# 37       416    62    478
# 35       417    57    474
# 36       403    53    456
# 54        33    51     84
# 56        20    50     70
# 55        34    48     82
# 33       398    44    442
# 53        34    40     74
# 57        37    38     75
# 34       414    33    447
# 31       371    33    404
# 60        30    32     62
# 32       386    32    418
# 59        32    30     62

# %% [markdown]
# As observed:
# - `Age` between 36 and 46 years old seems more often entry in churn.
#
# > Português
#
# Conforme observado:
# - `Idade` entre 36 e 46 anos parece mais frequentemente entrada na rotatividade.

# %%
pd.crosstab(df_churn['Tenure'], df_churn['Exited'], margins=True).sort_values(by=[1], ascending=False)
# Out:
# Exited     0     1    All
# Tenure
# All     7963  2037  10000
# 1        803   232   1035
# 3        796   213   1009
# 9        771   213    984
# 5        803   209   1012
# 4        786   203    989
# 2        847   201   1048
# 8        828   197   1025
# 6        771   196    967
# 7        851   177   1028
# 10       389   101    490
# 0        318    95    413

# %% [markdown]
# As observed:
# - `Tenure` seems has not any influence for customer entry in churn.
#
# >Português
#
# Conforme observado:
# - `Tenure` parece não ter qualquer influência para a entrada do cliente no churn.

# %%
pd.crosstab(df_churn['NumOfProducts'], df_churn['Exited'], margins=True).sort_values(by=[1], ascending=False)
# Out:
# Exited            0     1    All
# NumOfProducts
# All            7963  2037  10000
# 1              3675  1409   5084
# 2              4242   348   4590
# 3                46   220    266
# 4                 0    60     60

# %% [markdown]
# As observed:
# - `NumOfProducts` seems has any influence for customer not entry in churn when more than one per customer.
#
# >Português
#
# Conforme observado:
# - `NumOfProducts` parece ter alguma influência para o cliente não entrar no churn quando mais de um por cliente.

# %%
#HasCrCard
pd.crosstab(df_churn['HasCrCard'], df_churn['Exited'], margins=True).sort_values(by=[1], ascending=False)
# Out:
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945

# %% [markdown]
# As observed:
# - `HasCrCard` seems has any influence for customer entry in churn when he has it.
#
# > Português
#
# Conforme observado:
# - `HasCrCard` parece ter alguma influência para a entrada do cliente no churn quando ele o possui.

# %%
pd.crosstab(df_churn['IsActiveMember'], df_churn['Exited'], margins=True).sort_values(by=[1], ascending=False)
# Out:
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151

# %% [markdown]
# As observed:
# - `IsActiveMember` seems has any influence for customer entry in churn when he is not Active.
#
# >Português
#
# Conforme observado:
# - `IsActiveMember` parece ter qualquer influência para a entrada do cliente no churn quando ele não está ativo.

# %%
# creates a box plot of percentage income by loan status
plt.figure(figsize=(6, 10))

plt.title('Average Balance by Churn Status')
plt.suptitle('')

sns.boxplot(x='Exited' , y='Balance', data=df_churn)

plt.xticks([0, 1], ['Not Churn', 'Churn'])

plt.show()

# %% [markdown]
# As observed:
# - It seems customers with lower `Balance` not trend to entry in churn.
#
# > Português
#
# Conforme observado:
# - Parece que os clientes com menor `Balance` não tendem a entrar em churn.

# %%
# creates a box plot of percentage income by loan status
plt.figure(figsize=(6, 10))

plt.title('Average Credit Score by Churn Status')
plt.suptitle('')

sns.boxplot(x='Exited' , y='CreditScore', data=df_churn)

plt.xticks([0, 1], ['Not Churn', 'Churn'])

plt.show()

# %% [markdown]
# As observed:
# - It seems customers `CreditScore` does not influence the trend to entry in churn.
#
# >Português
#
# Conforme observado:
# - Parece que o `CreditScore` dos clientes não influencia a tendência de entrada em churn.

# %% [markdown]
# ## 4.4 Checking Outliers

# %%
df_churn.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ### 4.4.1 By Scatterplot

# %%
# plots a scatter plot of income against age
plt.figure(figsize=(8, 6))

plt.scatter(df_churn['Exited'], df_churn['EstimatedSalary'], color='blue', alpha=0.25)
plt.xlabel('Exit')
plt.ylabel('Estimated Salary')

# prevents scientific notation on axis
plt.ticklabel_format(useOffset=False, style='plain')

plt.show()

# %% [markdown]
# As observed:
# - It seems customers `EstimatedSalary` is balanced.
#
# >Português
#
# Conforme observado:
# - Parece que o `EstimatedSalary` dos clientes está equilibrado.

# %% [markdown]
# ### 4.4.2 Finding Outliers with Cross Tables

# %% [markdown]
# Now we need to find and remove outliers we suspect might be in the data. We can use cross tables and aggregate functions. Have a look at the `Balance` column. To detect outliers we can use functions like `min` and `max`.
#
# >Português
#
# Agora precisamos encontrar e remover outliers que suspeitamos estarem nos dados. Podemos usar tabelas cruzadas e funções agregadas. Dê uma olhada na coluna `Balance`. Para detectar outliers, podemos usar funções como `min` e` max`.

# %%
# creates the cross table for Exited status, Gender, and the max Balance
pd.crosstab(df_churn['Exited'],df_churn['Gender'],
        values=df_churn['Balance'], aggfunc='max')
# Out:
# Gender     Female       Male
# Exited
# 0       212778.20  221532.80
# 1       238387.56  250898.09

# %% [markdown]
# As observed:
# - It seems customers `Balance` is balanced.
#
# >Português
#
# Conforme observado:
# - Parece que o `equilíbrio` dos clientes está equilibrado.

# %% [markdown]
# ## 4.5 Checking Missing Data

# %%
# checks how many null records for each column 
df_churn.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## 4.6 Checkpoint

# %%
# saves the data set state
df_churn.to_csv('data/churn_clean.csv', index=False)

# %% [markdown]
# # 5.0 Outlining the Hypotheses
# ---

# %% [markdown]
# ## 5.1 Hypotheses Table

# %% [markdown]
# |H N#|Hypothesis      |Description  |Supposition                                                                     |
# |:---|:---------------|:------------|:-------------------------------------------------------------------------------|
# |01  | Age            | > 35 & <=52 |The data show that customers with age between 35 a 52 trend more entry in churn |
# |02  |Balance         | Mean > 120K |The data show that customers with balance mean > 120K trend more entry in chhurn|
# |03  |Has Credit Card | Has         |The data shows that customers wih Credit Card trend entry in churn              |
# |04  |Geography       | Germany & France|`Germany` and `France` have the most number of customers in churn           |
# |05  |Gender          | Female      |`Female` is the gender of the most number of customers in churn                 |
# |06  |Num Of Products | = 1         |Customers with only one bank products trend entry in churn                      |
# |07 |Is Active Member | NOT Active  |Customers Not Active trend entry in churn                                       |

# %% [markdown]
# # 6.0 Exploratory data analysis
# ---

# %% [markdown]
# ## 6.1 Loading data set

# %%
df_churn_cleaned = pd.read_csv("data/churn_clean.csv")
df_churn_cleaned.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# checks the size
df_churn_cleaned.shape
# Out:
# (10000, 11)

# %% [markdown]
# ## 6.2 Univariate analysis

# %% [markdown]
# ### 6.2.1 Target variable

# %%
exited_sts = df_churn_cleaned["Exited"].value_counts().reset_index().rename(columns={'index':'Exited','Exited':'Count'})

# %%
# Let´s see the distribuition of Exited Column by Count Plot and see the propottions of both status

# plots count
ax = sns.countplot(x=df_churn_cleaned['Exited'])

# sets the figure size in inches
ax.figure.set_size_inches(14, 6)

# set plot features
ax.set_title("Count for Existed Status", fontsize=16)
ax.set_ylabel("Nº de Clientes", fontsize=14)
ax.set_xlabel("Exited Status", fontsize=14)

# set xticks labels
plt.xticks([0, 1], ['NOT Churn', 'Churn'])

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', color='white', size=18)
    
# displays plot
plt.show()

# %%
# separating the data set for easier analysis
df_churn_active = df_churn[df_churn_cleaned['Exited'] == 0].copy()
df_churn_chruned = df_churn[df_churn_cleaned['Exited'] == 1].copy()

# %%
#counts the number of customes active and in Churn
total_active = df_churn_active.shape[0]
total_churned = df_churn_chruned.shape[0]
total_observations = df_churn.shape[0]

print('Number of Active Customers:', total_active)
print('This is equivalent to {:.2f}% of the total observations'.format((total_active/total_observations)*100))

print('\nNumber of Customers in Churn :', total_churned)
print('This is equivalent to {:.2f}% of the total observations'.format((total_churned/total_observations)*100))
# Out:
# Number of Active Customers: 7963
# This is equivalent to 79.63% of the total observations
#
# Number of Customers in Churn : 2037
# This is equivalent to 20.37% of the total observations

# %% [markdown]
# ↑↑ As we can see, we have more observations indicating clients in Active than Churn.
#
# →→ This dataset needs balancing approach, to maintain the same proportion of clients in churn and active to avoid any bias in AI Algorithm.
#
# >Português
#
# ↑↑ Como podemos ver, temos mais observações indicando clientes em Ativo do que em Churn.
#
# Este conjunto de dados precisa de uma abordagem de equilíbrio, para manter a mesma proporção de clientes em rotatividade e ativos para evitar qualquer tendência no Algoritmo de AI.

# %% [markdown]
# ### 6.2.2 Numerical Variables

# %%
# creates a dataset for numerical attributes
num_attributes = df_churn_chruned.select_dtypes(include=['int64', 'float64'])

# %%
# plots a histogram for all numerical attributes
_ = num_attributes.hist(bins=30, figsize=(20,20))

# %% [markdown]
# As we can observe, variables `Credit Score`, `Age` and `Balance` seems presents a normal distribution.
#
# >Português
#
# Como podemos observar, as variáveis `Credit Score`,` Age` e `Balance` parecem apresentar uma distribuição normal.

# %% [markdown]
# ### 6.2.3 Categorical variables

# %%
# creates a dataset for categorical attributes
cat_attributes = df_churn_cleaned.select_dtypes(exclude=['int64', 'float64'])

# %%
# uses the variable ax for a single Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(18,8)

# person_home_ownership
plt.subplot(1,2,1)
sns.countplot(x=cat_attributes['Geography'], 
              order=cat_attributes['Geography'].value_counts().index)
plt.title("Counts for Geography")

# loan_intent
plt.subplot(1, 2, 2)
sns.countplot(x=cat_attributes['Gender'], 
              order=cat_attributes['Gender'].value_counts().index)
plt.title("Counts for Gender")

# adjusts vertical space between plots
plt.subplots_adjust(hspace = 0.5)
plt.subplots_adjust(wspace = 0.5)

# display plots
plt.show()

# %% [markdown]
# ## 6.3 Bivariate analysis - Hypotheses validation

# %% [markdown]
# In this section, we're going to validate the hypothesis that we outlined in section 5.
#
# >Português
#
# Nesta seção, vamos validar as hipóteses que delineamos na seção 5.

# %% [markdown]
# ### H1. Customers with age between 35 and 52 years old trend more entry in churn. <font color='green'>(TRUE)
#
# Os clientes com idade entre 35 e 52 anos apresentam tendência de maior entrada no churn. <font color = 'green'> (VERDADEIRO)

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(25, 8)

# plots the graph
sns.countplot(x='Age', hue='Exited', data=df_churn_chruned, palette=["g"])

# sets plot title
ax.set_title("Churn Count Per Age", fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# sets the legend
plt.legend(title="Exited Status", labels=['Churn'], title_fontsize=15, fontsize=15)

# display plots
plt.show()

# %% [markdown]
# As observed, the most part of churn customer is between 35 and 52 years old.
#
# > Thus, the hypothesis is **TRUE**.
#
#
# Português
#
# Conforme observado, a maior parte do churn de clientes tem entre 35 e 52 anos.
#
# > Assim, a hipótese é ** VERDADEIRA **.

# %% [markdown]
# ### H2. Customers balance average equal or up 120 K trend more entry in churn. <font color='green'>(TRUE)
#
# Clientes com saldo médio igual ou superior a 120 K tendência a mais entrada no churn. <font color = 'green'> (VERDADEIRO)

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(6, 8)

# plots the graph
sns.boxplot(x='Exited', y='Balance',  data=df_churn_chruned, showfliers=False, palette=["b"])

# sets plot title
ax.set_title("Balance Statiscs by Exited Status", fontsize=20)

# set xticks labels
plt.xticks([0], ['Churn'])

# display plots
plt.show()

# %% [markdown]
# As observed, the mean balance for people who entry in Churn is equal or up 120 K
#
# > Thus, the hypothesis is **TRUE**.
#
# Português
#
# Conforme observado, o saldo médio para pessoas que ingressam no Churn é igual ou superior a 120 K
#
# > Assim, a hipótese é ** VERDADEIRA **.

# %% [markdown]
# ### H3. Customers with Credit Card trend entry in churn. <font color='green'>(TRUE)
#
# Clientes com tendência de entrada de cartão de crédito no churn. <font color = 'green'> (VERDADEIRO)

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(18, 8)

# plots the graph
sns.countplot(x='HasCrCard', hue='Exited', data=df_churn_chruned, 
              order=df_churn_cleaned['HasCrCard'].value_counts().index, palette=["r"])

# sets plot title
ax.set_title("Churn Count per Has Credit Card Status", fontsize=20)

# sets the legend
plt.legend(title="Exited Status", labels=['Churn'], title_fontsize=15, fontsize=15)

plt.xticks([0,1], ['Has','NOT Has'])

# display plots
plt.show()

# %% [markdown]
# As noted, Customers who have a Credit Card tend to enter into churn and those who do not, maintain loyalty.
#
# > Thus, the hypothesis is ** TRUE **.
#
# Português
#
# Conforme observado, Clientes que possuem Cartão de Crédito tendem a entrar no churn e aqueles que não possuem, mantêm a fidelidade.
#
# > Assim, a hipótese é ** VERDADEIRA **.

# %% [markdown]
# ### H4. Germany and France have the most number of customers in churn . <font color='green'>(TRUE)

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(18, 10)

# plots the graph
sns.countplot(x='Geography', hue='Exited', data=df_churn_chruned, palette=["y"])

# sets plot title
ax.set_title("Churn Count Per Geography", fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# sets the legend
plt.legend(title="Exited Status", labels=['Churn'], title_fontsize=15, fontsize=15)

# display plots
plt.show()

# %% [markdown]
# As noted, `Germany` and `France` are almost equal in number of customer in churn.
#
# > Thus, the hypothesis is ** TRUE **.

# %% [markdown]
# ### H5. `Female` is the gender of the most number of customers in churn . <font color='green'>(TRUE)

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(18, 10)

# plots the graph
sns.countplot(x='Gender', hue='Exited', data=df_churn_chruned, palette=["m"])

# sets plot title
ax.set_title("Churn Count Per Gender", fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# sets the legend
plt.legend(title="Exited Status", labels=['Churn'], title_fontsize=15, fontsize=15)

# display plots
plt.show()

# %% [markdown]
# As noted, Gender `Female` are almost in churn mode.
#
# > Thus, the hypothesis is ** TRUE **.
#
# Português
#
# Como observado, Gênero `Feminino` está quase no modo de rotatividade.
#
# > Assim, a hipótese é ** VERDADEIRA **.

# %% [markdown]
# ### H6. Customers with only one bank product trend entry in churn . <font color='green'>(TRUE)
#
# Clientes com apenas uma entrada de tendência de produto bancário no churn. <font color = 'green'> (VERDADEIRO)

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(18, 10)

# plots the graph
sns.countplot(x='NumOfProducts', hue='Exited', data=df_churn_chruned, palette="Reds")

# sets plot title
ax.set_title("Churn Count Per Gender", fontsize=20)

# sets the legend
plt.legend(title="Exited Status", labels=['Churn'], title_fontsize=15, fontsize=15)

# display plots
plt.show()

# %% [markdown]
# As noted, Customers with only 1 bank product trend to entry in churn.
#
# > Thus, the hypothesis is **<font color='green'>TRUE**.
#
# Português
#
# Conforme observado, os Clientes com apenas 1 produto bancário tendem a entrar em churn.
#
# > Assim, a hipótese é ** <font color = 'green'> VERDADEIRA **.

# %% [markdown]
# ### H7. Customers Not Active trend entry in churn . <font color='green'>(TRUE)
#
# Entrada de tendência de clientes não ativos no churn. (VERDADEIRO)

# %%
 #uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(18, 10)

# plots the graph
sns.countplot(x='IsActiveMember', hue='Exited', data=df_churn_chruned, palette="Reds")

# sets plot title
ax.set_title("Churn Count Per Is Active Member Status", fontsize=20)

# sets the legend
plt.legend(title="Is Active Member Status", labels=['NOT Active'], title_fontsize=15, fontsize=15)

plt.xticks([0,1], ['NOT Active','Active'])

# display plots
plt.show()

# %% [markdown]
# As noted, Customers Not Activer trend to entry in churn.
#
# > Thus, the hypothesis is **<font color='green'>TRUE**.
#
# Português
#
# Conforme observado, os clientes não ativados tendem a entrar no churn.
#
# > Assim, a hipótese é ** <font color = 'green'> VERDADEIRA **.

# %% [markdown]
# ### 6.3.1 Hypotheses Summary

# %% [markdown]
# | ID  | Hypothesis                                                                  | Conclusion |
# |:---:|:----------------------------------------------------------------------------|:----------:|
# | H1  | Customers with age between 35 and 52 years old trend more entry in churn    | True       |
# | H2  | Customers *balance average equal or up 120 K* trend more entry in churn     | True       |
# | H3  | Customers *wih Credit Card* trend entry in churn                            | True       |
# | H4  | *Germany* and *France* have the most number of customers in churn           | True       |
# | H5  | *Female* is the gender of the most number of customers in churn             | True       |
# | H6  | Customers with *only one bank product* trend entry in churn                 | True       |
# | H7  | Customers *Not Active* trend entry in churn                                 | True       |

# %% [markdown]
# ## 6.4 Multivariate analysis - Correlations

# %% [markdown]
# ### 6.4.1 Correlation between numerical attributes (explanatory vars)

# %%
# drops target var
num_attributes = num_attributes.drop('Exited', axis=1)

# %%
# gets the correlation between the numerical variables
correlation = num_attributes.corr(method='pearson')

# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(12, 8)

# generates a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=np.bool))

# generates a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# plots the heatmap
sns.heatmap(correlation, cmap=cmap, mask=mask, square=True, linewidths=.5, annot=True)

# displays the plot
plt.show()
# Out:
# C:\Users\sandr\AppData\Local\Temp/ipykernel_2584/693202559.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(correlation, dtype=np.bool))

# %% [markdown]
# # 7.0 Data preprocessing
# ---

# %% [markdown]
# ## 7.1 Loading data set

# %%
# loads data set
df_churn_cleaned = pd.read_csv('data/churn_clean.csv')
df_churn_cleaned.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ## 7.3 Encoding Data

# %%
# Geography
df_churn_cleaned['Geography']= pd.Categorical(df_churn_cleaned['Geography'])
df_churn_cleaned['Geo_Cat'] = df_churn_cleaned['Geography'].cat.codes

# Gender
df_churn_cleaned['Gender']= pd.Categorical(df_churn_cleaned['Gender'])
df_churn_cleaned['Gen_Cat'] = df_churn_cleaned['Gender'].cat.codes

# %%
# Drop Text Columns
df_churn_cleaned =  df_churn_cleaned.drop(["Geography","Gender"],axis=1)

# %%
df_churn_cleaned.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geo_Cat  Gen_Cat
# 0               1        101348.88       1        0        0
# 1               1        112542.58       0        2        0
# 2               0        113931.57       1        0        0
# 3               0         93826.63       0        0        0
# 4               1         79084.10       0        2        0

# %% [markdown]
# ## 7.4 Split Data Set into Train and Test

# %%
# creates the X and y data sets
X = df_churn_cleaned.drop('Exited', axis=1).values
y = df_churn_cleaned['Exited'].values

# splits into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, 
                                                        random_state=1234, stratify=y)

# %% [markdown]
# ## 7.5 Balancing Data for Training

# %%
# counts the number of classes before oversampling
print('Before balancing:', Counter(y_train))

# defines the resampler
resampler = SMOTETomek(random_state=1234, n_jobs=-1)

# transforms the data set
X_balanced, y_balanced = resampler.fit_resample(X_train, y_train)

# counts the number of classes after oversampling
print('After balancing:', Counter(y_balanced))
# Out:
# Before balancing: Counter({0: 5972, 1: 1528})
# After balancing: Counter({0: 5157, 1: 5157})

# %%
#plots before and after SMOTE
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x=y_train)
plt.title("Before SMOTE")

plt.subplot(1,2,2)
sns.countplot(x=y_balanced)
plt.title("After SMOTE")

plt.show()

# %% [markdown]
# ## 7.6 Scaling Data for Training and Test

# %%
# preprocessing - normalization
scaler = StandardScaler()
scaler.fit(X_balanced)
x_train_scaled = scaler.transform(X_balanced)
x_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # 8. Deep Learning Modeling
# ---

# %% [markdown]
# ## 8.1 First TensorFlow Model

# %%
model = models.Sequential()
model.add(layers.Dense(8, activation='relu', input_shape=(x_train_scaled.shape[1],)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(1))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 8)                 88
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                144
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# ...
# Total params: 249
# Trainable params: 249
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# compile model using rmsprop
#model.compile(optimizer='rmsprop',loss='mse',metrics=['mse'])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# model training
history = model.fit(x_train_scaled, y_balanced, validation_split=0.2, epochs=10)
# Out:
# Epoch 1/10
# 258/258 [==============================] - 1s 2ms/step - loss: 3.2295 - accuracy: 0.6171 - val_loss: 2.2640 - val_accuracy: 0.3509
# Epoch 2/10
# 258/258 [==============================] - 0s 1ms/step - loss: 1.8328 - accuracy: 0.6225 - val_loss: 2.0812 - val_accuracy: 0.2603
# Epoch 3/10
# 258/258 [==============================] - 0s 1ms/step - loss: 1.5020 - accuracy: 0.6188 - val_loss: 1.5276 - val_accuracy: 0.2797
# Epoch 4/10
# 258/258 [==============================] - 0s 1ms/step - loss: 1.3210 - accuracy: 0.6354 - val_loss: 1.5780 - val_accuracy: 0.2075
# Epoch 5/10
# 258/258 [==============================] - 0s 1ms/step - loss: 1.1786 - accuracy: 0.6334 - val_loss: 1.1274 - val_accuracy: 0.2889
# Epoch 6/10
# 258/258 [==============================] - 0s 1ms/step - loss: 1.0405 - accuracy: 0.6320 - val_loss: 1.0910 - val_accuracy: 0.2191
# Epoch 7/10
# ...

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 79/79 [==============================] - 0s 964us/step - loss: 1.0693 - accuracy: 0.6144
# [1.069295048713684, 0.6144000291824341]

# %% [markdown]
# ## 8.2 Turnning TensorFlow Model

# %% [markdown]
# ### 8.2.1 Turnning TensorFlow Model

# %%
# Create a Hyper Model
class RegressionHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape
    def build(self, hp):
        model = keras.Sequential()
        model.add(
            layers.Dense(
                units=hp.Int('units', 8, 64, 4, default=8),                
                activation=hp.Choice(
                    'dense_activation',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'),
                input_shape=input_shape
            )
        )
        
        model.add(
            layers.Dense(
                units=hp.Int('units', 16, 64, 4, default=16),                
                activation=hp.Choice(
                    'dense_activation',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu')
            )
        )
        
        model.add(
            layers.Dropout(
                hp.Float(
                    'dropout',
                    min_value=0.0,
                    max_value=0.1,
                    default=0.005,
                    step=0.01)
            )
        )
        
        model.add(layers.Dense(1))
        
        model.compile(
            
            loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']
        )         
        
        
        return model

# %%
input_shape = (X_balanced.shape[1],)
hypermodel = RegressionHyperModel(input_shape)

# %% [markdown]
# ### 8.2.2 Turning TensorFlow Model

# %% [markdown]
# #### 8.2.2.1 Turning TensorFlow Model by Random Search Tuner

# %%
tuner_rs = RandomSearch(
            hypermodel,
            objective='accuracy',
            max_trials=10,
            seed=1234,
            executions_per_trial=2,
            project_name="turner_rs",
            directory="tuner_rs"
            )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project tuner_rs\turner_rs\oracle.json
# INFO:tensorflow:Reloading Tuner from tuner_rs\turner_rs\tuner0.json

# %%
tuner_rs.search(x_train_scaled, y_balanced, epochs=10, validation_split=0.2, verbose=0)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
best_model_by_rs = tuner_rs.get_best_models(num_models=1)[0]
loss, accuracy = best_model_by_rs.evaluate(x_test_scaled, y_test)
# Out:
# 79/79 [==============================] - 0s 913us/step - loss: 0.4924 - accuracy: 0.7956

# %% [markdown]
# #### 8.2.2.2 Turning TensorFlow Model by Bayseian Optmization Tuner

# %%
tuner_bo = BayesianOptimization(
            hypermodel,
            objective='accuracy',
            max_trials=10,
            seed=1234,
            executions_per_trial=2,
            project_name="tuner_bo",
            directory="tuner_bo"
        )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project tuner_bo\tuner_bo\oracle.json
# INFO:tensorflow:Reloading Tuner from tuner_bo\tuner_bo\tuner0.json

# %%
tuner_bo.search(x_train_scaled, y_balanced, epochs=10, validation_split=0.2, verbose=0)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
best_model_by_bo = tuner_bo.get_best_models(num_models=1)[0]
best_model_by_bo.evaluate(x_test_scaled, y_test)
# Out:
# 79/79 [==============================] - 0s 785us/step - loss: 0.4911 - accuracy: 0.8336
# [0.49112793803215027, 0.8335999846458435]

# %% [markdown]
# #### 8.2.2.3 Turning TensorFlow Model by HyperBand Tuner

# %%
tuner_hb = Hyperband(
            hypermodel,
            max_epochs=5,
            objective='accuracy',
            seed=1234,
            executions_per_trial=2,
             project_name="tuner_hb",
            directory="tuner_hb"
        )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project tuner_hb\tuner_hb\oracle.json
# INFO:tensorflow:Reloading Tuner from tuner_hb\tuner_hb\tuner0.json

# %%
tuner_hb.search(x_train_scaled, y_balanced, epochs=10, validation_split=0.2, verbose=0)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
best_model_by_hb = tuner_hb.get_best_models(num_models=1)[0]
best_model_by_hb.evaluate(x_test_scaled, y_test)
# Out:
# 79/79 [==============================] - 0s 764us/step - loss: 0.4388 - accuracy: 0.8296
# [0.43884214758872986, 0.8295999765396118]

# %% [markdown]
# # 9. Best Model Fit and Predict
# Melhor ajuste e previsão do modelo

# %% [markdown]
# * Random Search Tuner - Accuracy: **0.7956**
# * Bayesian Optimization Tuner - Accuracy: **0.8336**
# * HyperBand Tuner - Accuracy: **0.8296**
#
# **As noted, the best model turner was Bayesian Optimization, so we will use the best hyper parameters of it to create a final model**
#
# >Português
#
# * Random Search Tuner - Precisão: ** 0,7956 **
# * Bayesian Optimization Tuner - Precisão: ** 0,8336 **
# * HyperBand Tuner - Precisão: ** 0,8296 **
#
# ** Como observado, o melhor virador de modelo foi a Otimização Bayesiana, então usaremos os melhores hiperparâmetros dele para criar um modelo final **

# %%
# Fit the Best Model with Test Data
best_model_by_bo.fit(x_test_scaled ,y_test)
# Out:
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4918 - accuracy: 0.8328

# %%
# Return the Prediction Probability from Test Data
predictions = best_model_by_rs.predict(x=x_test_scaled, batch_size=32)

# %%
# Print Some Probability 
print(
    "This particular customer had a %.1f percent probability "
    "of entry in churn, as evaluated by our model." % (100 * predictions[1][0],)
)
# Out:
# This particular customer had a 69.5 percent probability of entry in churn, as evaluated by our model.

# %% [markdown]
# Esse cliente em particular tinha 69,5% de probabilidade de entrada no churn, conforme avaliado por nosso modelo.

# %% [markdown]
# **So the Business Area could establish to "attack" clients with 60%  or more of probability to entry in churn.**
#
# ** Assim, a Área de Negócios poderia se estabelecer como “atacar” clientes com 60% ou mais de probabilidade de entrada em churn. **

# %% [markdown]
# # 10. Solution Implementation in Business
#
# Implementação da Solução no Negócio

# %% [markdown]
# ## 10.1 - Business Goal Review
# Revisão de meta de negócios

# %% [markdown]
# ### Create a business solution with Business Areas to reduce the churn rate in 10% in planned mid-term !
#
# Crie uma solução de negócios com as áreas de negócios para reduzir o churn rate em 10% no médio prazo planejado!

# %% [markdown]
# ## 10.2 - Actual Scenario - Baseline
# Cenário real - linha de base

# %% [markdown]
# * Today, the organization has 2.000 clients in churn as data shows;
# * The organization has revenue $ 10.00 per client;
# * With 2.000 in churn, the revenue loss are about $ 20.000;
# * Today, Marketing Area has no any type of information to direct more efficiently in its retention initiatives.

# %% [markdown]
# ## 10.3 - Implementation Steps

# %% [markdown]
# >### 10.3.1 - Analytics Department - Predictive Model Implementation
# Departamento de Análise - Implementação do Modelo Preditivo

# %% [markdown]
# > 1. Each month, Analytics Department extract a list fo clients with some information that will be use in prediction step;
# > 2. The Analytics Department submit to prediction solution these data;
# > 3. The prediction solution generates a report with clients and his probability to entry in churn;
# > 4. The Analytics Department send this report to Marketing and/or Retention Departments;
#
# Português
#
# > 1. Mensalmente, o Departamento de Analytics extrai uma lista de clientes com algumas informações que serão utilizadas na etapa de previsão;
# > 2. O Departamento de Analytics submete à solução de previsão esses dados;
# > 3. A solução de previsão gera um relatório com os clientes e sua probabilidade de entrada no churn;
# > 4. O Departamento de Analytics envia este relatório aos Departamentos de Marketing e / ou Retenção;

# %% [markdown]
# ### 10.4 - Business Areas
# Áreas de negócios

# %% [markdown]
# > With the Clients Churn Probabilities in hands, the Marketing or Retention Area can follow below steps:
# >> 1. Do retention iniatives with more priority in clients with high probabilities.
# >> 1. Avoid "attack" clients more than once in a short time that can destroy the retention strateg
# >> 1. Can mesure more efficient its success on retention iniatives
#
# Português
#
# > Com as Probabilidades de Churn de Clientes em mãos, a Área de Marketing ou Retenção pode seguir os seguintes passos:
# >> 1. Faça iniciativas de retenção com mais prioridade em clientes com altas probabilidades.
# >> 1. Evite "atacar" clientes mais de uma vez em um curto espaço de tempo, o que pode destruir a estratégia de retenção
# >> 1. Pode medir com mais eficiência seu sucesso em iniciativas de retenção

# %% [markdown]
# # 11 - Business Revenue Estimatives with Solution Implementation

# %% [markdown]
# > 1. Since predict model´s accuracy is about 83%, each 10 clients batch, 8 clients have higher chance to entry in churn;
# > 1. Statisticis shows that new client conquest is 5x more expensive that keep it. Guessing that investment is 7.00 to keep client, one new client costs 35.00.
#
# ### So, for each client keeped, the organization maintain its revenue per client that is 10.00, and avoid waste 35.00
#
# >Português
#
# > 1. Como a precisão do modelo de previsão é de cerca de 83%, a cada lote de 10 clientes, 8 clientes têm maior chance de entrada no churn;
# > 1. A estatística mostra que a conquista de novos clientes é 5x mais cara do que mantê-los. Supondo que o investimento seja de 7,00 para manter o cliente, um novo cliente custa 35,00.
#
# ### Assim, para cada cliente mantido, a organização mantém sua receita por cliente que é de 10,00, e evita o desperdício de 35,00

# %% [markdown]
# # 12 - Solution Implementation Strategies
# Estratégias de implementação de soluções

# %% [markdown]
# ### 12.1 Business Goal is maintain churn rate on 10%.
# ### 12.2 Churn rate on 10% means 1.000 more in active mode, that means 1.000 x 45.00 ( Revenue 10.00 + Avoid New Client Investiment 35.00) = 45.000 as Revenue for organization.
#
# >Português
#
# ### 12.1 O objetivo do negócio é manter a taxa de rotatividade em 10%.
# ### 12.2 Taxa de churn de 10% significa 1.000 a mais no modo ativo, o que significa 1.000 x 45,00 (Receita 10,00 + Evitar Investimento de Novo Cliente 35,00) = 45.000 como Receita para a organização.
